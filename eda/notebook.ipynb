# %%
import pandas as pd
import seaborn as sns

# %%
main_sample_df = pd.read_csv("./sample_data/label.csv")
sample_df = main_sample_df.copy()
sample_df
# Out:
#          video_id  clip_id                                               text  \
# 0     03bSnISJMiM       11                                 A LOT OF SAD PARTS
# 1     03bSnISJMiM       10                                  THERE IS SAD PART
# 2     03bSnISJMiM       13                             AND ITS A REALLY FUNNY
# 3     03bSnISJMiM       12                   BUT IT WAS REALLY REALLY AWESOME
# 4     03bSnISJMiM        1                          ANYHOW IT WAS REALLY GOOD
# ...           ...      ...                                                ...
# 2194  zhpQhgha_KU       30  BECAUSE THERE REALLY WASNT ALL THAT MUCH TO IT...
# 2195  zhpQhgha_KU       35  UM SO IF YOU LIKE TO HEAR A UM LIKE MORE POSIT...
# 2196  zhpQhgha_KU       34                    AND SHE REALLY ENJOYED THE FILM
# 2197  zhpQhgha_KU       33  IF YOU DO WANNA SEE SOMEBODY WHOS POSSIBLY CRI...
# 2198  zhpQhgha_KU       32  UM YEAH I MEAN IF YOU WANNA SEE A VIDEO UM ITS...
#
# ...

# %%
sample_df = sample_df.query('video_id == "_dI--eQ6qVU"')
sample_df
# Out:
#          video_id  clip_id                                               text  \
# 1360  _dI--eQ6qVU       24                     BUT THEY TOOK A NEW SPIN ON IT
# 1361  _dI--eQ6qVU       25                                AND I JUST LOVED IT
# 1362  _dI--eQ6qVU       26  AND I FEEL LIKE EVEN THOUGH THE FIGHTING SEQUE...
# 1363  _dI--eQ6qVU       27  SO I MEANT IF I WAS WEARING 3D GLASSES AND WAS...
# 1364  _dI--eQ6qVU       20                                 AND JUST DIFFERENT
# 1365  _dI--eQ6qVU       21                       IT ENGAGES THE AUDIENCE MORE
# 1366  _dI--eQ6qVU       22                       AND I JUST REALLY ENJOYED IT
# 1367  _dI--eQ6qVU       23             THE GREEN HORNET DID SOMETHING SIMILAR
# 1368  _dI--eQ6qVU       28  AND I WOULD WANT THE SEQUENCES TO BE EVEN LONG...
# 1369  _dI--eQ6qVU        1  BUT I CAN SAFELY ASSURE YOU THAT EVEN IF THEY ...
# 1370  _dI--eQ6qVU        3  I DONT KNOW IF FANS OF THE COMIC WOULD BE AS I...
# ...

# %%
sample_df.shape
# Out:
# (28, 9)
